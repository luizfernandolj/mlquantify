# %%
import pandas as pd
import numpy as np

from quantifyML import *
# Out:
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 29 ("    'E57373', 'F06292', 'BA68C8', '9575CD', '64B5F6', '4FC3F7', '4DB6AC',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 30 ("    '4CAF50', '81C784', 'AED581', 'DCE775', 'FFF176', 'FFD54F', 'FFB74D',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 31 ("    'FF8A65', 'FF7043', 'BF360C', 'D32F2F', 'C2185B', '7B1FA2', '512DA8',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 32 ("    '303F9F', '1976D2', '0288D1', '0097A7', '00796B', '388E3C', '689F38',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 33 ("    'AFB42B', 'FBC02D', 'F57F17', 'F9A825', 'F57C00'")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 34 ('])')
# Bad value in file 'quantifyML/plots/style.mplstyle', line 28 ("axes.prop_cycle    : cycler('color', ["): Key axes.prop_cycle: "cycler('color', [" is not a valid cycler construction: '[' was never closed (<unknown>, line 1)
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 29 ("    'E57373', 'F06292', 'BA68C8', '9575CD', '64B5F6', '4FC3F7', '4DB6AC',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 30 ("    '4CAF50', '81C784', 'AED581', 'DCE775', 'FFF176', 'FFD54F', 'FFB74D',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 31 ("    'FF8A65', 'FF7043', 'BF360C', 'D32F2F', 'C2185B', '7B1FA2', '512DA8',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 32 ("    '303F9F', '1976D2', '0288D1', '0097A7', '00796B', '388E3C', '689F38',")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 33 ("    'AFB42B', 'FBC02D', 'F57F17', 'F9A825', 'F57C00'")
# Missing colon in file 'quantifyML/plots/style.mplstyle', line 34 ('])')
# Bad value in file 'quantifyML/plots/style.mplstyle', line 28 ("axes.prop_cycle    : cycler('color', ["): Key axes.prop_cycle: "cycler('color', [" is not a valid cycler construction: '[' was never closed (<unknown>, line 1)

# %%
df = pd.read_csv("app_table.csv")
df = convert_columns_to_arrays(df)
df = round_protocol_df(df, 3)
df
# Out:
#      QUANTIFIER  REAL_PREVS      PRED_PREVS  BATCH_SIZE     ae    nae
# 0            CC  [0.0, 1.0]      [0.0, 1.0]          10  0.000  0.000
# 1           PCC  [0.0, 1.0]  [0.167, 0.833]          10  0.167  0.083
# 2           EMQ  [0.0, 1.0]    [0.58, 0.42]          10  0.580  0.290
# 3            FM  [0.0, 1.0]  [0.831, 0.169]          10  0.831  0.415
# 4           GAC  [0.0, 1.0]      [1.0, 0.0]          10  1.000  0.500
# ...         ...         ...             ...         ...    ...    ...
# 1195     DySsyn  [1.0, 0.0]      [0.0, 1.0]         110  1.000  0.500
# 1196        HDy  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
# 1197        SMM  [1.0, 0.0]  [0.948, 0.052]         110  0.052  0.026
# 1198       SORD  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
# 1199        HDx  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
#
# [1200 rows x 6 columns]

# %%
""" boxplot_params = {
    'medianprops': {'color': 'red', 'linewidth': 2},
    'whiskerprops': {'linewidth': 1},
    'capprops': {'linewidth': 1},
    'boxprops': {'linewidth': 1}
} """

boxplot_params = None


protocol_boxplot(table_protocol=df,
                  methods=["DyS", "EMQ", "FM", "CC"],  # ou "all"
                  x="QUANTIFIER",
                  y="nae",
                  order="rank",
                  save_path="boxplot.pdf",
                  title="Absolute Error Distribution",
                  plot_params=boxplot_params)

# %%
lineplot_params = None

""" lineplot_params = {
    'figsize': (8, 4),
    'linestyle': '--',
    'linewidth': 2,
    'markersize': 10
} """

protocol_lineplot(table_protocol=df,
                  methods=["DyS", "EMQ", "FM", "CC"],  # ou "all"
                  x="ALPHA",
                  y="nae",
                  pos_alpha=1,
                  save_path="lineplot-batch.pdf",
                  title="Normalized Absolute Error Distribution",
                  plot_params=lineplot_params)

# %%
# Exemplo de conjuntos de valores para cada classe
values = [
    np.random.normal(loc=0, scale=1, size=100),  # Conjunto de valores para a Classe 1
    np.random.normal(loc=4, scale=1, size=100)  # Conjunto de valores para a Classe 3
]

labels = ['Classe 1', 'Classe 2']

class_distribution_plot(values=values, 
                        labels=labels,
                        bins=30,
                        save_path="class_hist.pdf", 
                        title='Class Distribution Test')
