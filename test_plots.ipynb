# %%
import pandas as pd
import numpy as np

from quantifyML import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 import numpy as np
# ----> 4 from quantifyML import *
#
# File c:\Users\Luiz Fernando\Projects\Quantification\QuantifyML\quantifyML\__init__.py:5
#       3 from .methods import *
#       4 from .utils import *
# ----> 5 from .plots import *
#       6 from .model_selection import GridSearchQ
#
# File c:\Users\Luiz Fernando\Projects\Quantification\QuantifyML\quantifyML\plots\__init__.py:1
# ----> 1 from .protocol_plot import protocol_boxplot, protocol_lineplot
#
# ImportError: cannot import name 'protocol_boxplot' from 'quantifyML.plots.protocol_plot' (c:\Users\Luiz Fernando\Projects\Quantification\QuantifyML\quantifyML\plots\protocol_plot.py)

# %%
df = pd.read_csv("app_table.csv")
df = convert_columns_to_arrays(df)
df = round_protocol_df(df, 3)
df
# Out:
#      QUANTIFIER  REAL_PREVS      PRED_PREVS  BATCH_SIZE     ae    nae
# 0            CC  [0.0, 1.0]      [0.0, 1.0]          10  0.000  0.000
# 1           PCC  [0.0, 1.0]  [0.167, 0.833]          10  0.167  0.083
# 2           EMQ  [0.0, 1.0]    [0.58, 0.42]          10  0.580  0.290
# 3            FM  [0.0, 1.0]  [0.831, 0.169]          10  0.831  0.415
# 4           GAC  [0.0, 1.0]      [1.0, 0.0]          10  1.000  0.500
# ...         ...         ...             ...         ...    ...    ...
# 1195     DySsyn  [1.0, 0.0]      [0.0, 1.0]         110  1.000  0.500
# 1196        HDy  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
# 1197        SMM  [1.0, 0.0]  [0.948, 0.052]         110  0.052  0.026
# 1198       SORD  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
# 1199        HDx  [1.0, 0.0]      [1.0, 0.0]         110  0.000  0.000
#
# [1200 rows x 6 columns]

# %%
protocol_boxplot(table_protocol=df,
                  methods=None,  # ou "all"
                  x="QUANTIFIER",
                  y="ae",
                  title="Absolute Error Distribution",
                  plot_params={"figure.figsize": (8, 5)})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 protocol_boxplot(table_protocol=df,
#       2                   methods=None,  # ou "all"
#       3                   x="QUANTIFIER",
#       4                   y="ae",
#       5                   title="Absolute Error Distribution",
#       6                   plot_params={"figure.figsize": (8, 5)})
#
# File c:\Users\Luiz Fernando\Projects\Quantification\QuantifyML\quantifyML\plots\protocol_plot.py:104, in protocol_boxplot(table_protocol, methods, x, y, title, legend, save_path, plot_params)
#      90 """
#      91 Plots a boxplot based on the provided DataFrame and selected methods.
#      92
#    (...)
#     101 - plot_params (Dict[str, Any], optional): Additional plotting parameters.
#     102 """
#     103 # Filter data for specified methods
# --> 104 filtered_data = table_protocol[table_protocol["QUANTIFIER"].isin(methods)]
#     106 fig, ax = plt.subplots()
#     107 ax.set_aspect('equal')
#
# File c:\Users\Luiz Fernando\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:5550, in Series.isin(self, values)
#    5477 def isin(self, values) -> Series:
#    5478     """
#    5479     Whether elements in Series are contained in `values`.
#    5480
#    (...)
#    5548     dtype: bool
#    5549     """
# -> 5550     result = algorithms.isin(self._values, values)
#    5551     return self._constructor(result, index=self.index, copy=False).__finalize__(
#    5552         self, method="isin"
#    5553     )
#
# File c:\Users\Luiz Fernando\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:477, in isin(comps, values)
#     472     raise TypeError(
#     473         "only list-like objects are allowed to be passed "
#     474         f"to isin(), you passed a `{type(comps).__name__}`"
#     475     )
#     476 if not is_list_like(values):
# --> 477     raise TypeError(
#     478         "only list-like objects are allowed to be passed "
#     479         f"to isin(), you passed a `{type(values).__name__}`"
#     480     )
#     482 if not isinstance(values, (ABCIndex, ABCSeries, ABCExtensionArray, np.ndarray)):
#     483     orig_values = list(values)
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a `NoneType`
